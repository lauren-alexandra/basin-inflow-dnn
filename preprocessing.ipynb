# %%
import warnings
warnings.simplefilter("ignore")

import pandas as pd
import numpy as np

# %%
# Import data

DATA_PATH = 'Reservoir_Project/Data'

# %%
basin_inflow = pd.read_excel(f'{DATA_PATH}/Custom/basin_inflow_no_dates.xlsx', index_col=0)

# %%
basin_inflow.head()
# Out:
#    INFLOW  NFD_MEAN_FLOW  OXB_RIVER_STAGE  OXB_RIVER_DISCHARGE  \
# 0     977            152         8.585417           169.666667
# 1    1061            134         8.487917           153.958333
# 2    1712            126         8.343333           132.750000
# 3    1712            126         9.907083           752.833333
# 4    7072            126        10.882500           927.250000
#
#    CBR_RIVER_STAGE  CBR_RIVER_DISCHARGE  ADR_PRECIP_ACC  ADR_PRECIP_INCR  \
# 0         4.445833           281.045455            9.52             0.00
# 1         2.298750           722.583333            9.52             0.00
# 2         2.993333          1115.916667            9.76             0.24
# 3         2.649583           866.958333           11.28             1.52
# 4         3.432083          1273.791667           11.96             0.68
#
#    ADR_TEMP_AVG  ADR_TEMP_MAX  ...  FRN_SNOW_DEPTH  FRN_SNOW_WATER_CONTENT  \
# 0            44            58  ...              30                    7.90
# 1            47            57  ...              30                    7.88
# 2            45            50  ...              30                    7.86
# 3            46            50  ...              33                    8.27
# 4            41            46  ...              33                    8.27
#
#    FRN_TEMP_AVG  FRN_TEMP_MAX  FRN_TEMP_MIN  PFH_PRECIP_ACC  PFH_PRECIP_INCR  \
# 0            44            55            37            7.72             0.04
# 1            38            46            32            7.76             0.04
# 2            30            35            25            7.76             0.00
# 3            31            33            28           11.00             3.24
# 4            31            33            28           12.04             1.04
#
#    PFH_TEMP_AVG  PFH_TEMP_MAX  PFH_TEMP_MIN
# 0            40            61            30
# 1            39            63            29
# 2            40            53            29
# 3            39            47            32
# 4            33            38            32
#
# [5 rows x 39 columns]

# %%
basin_inflow.columns
# Out:
# Index(['INFLOW', 'NFD_MEAN_FLOW', 'OXB_RIVER_STAGE', 'OXB_RIVER_DISCHARGE',
#        'CBR_RIVER_STAGE', 'CBR_RIVER_DISCHARGE', 'ADR_PRECIP_ACC',
#        'ADR_PRECIP_INCR', 'ADR_TEMP_AVG', 'ADR_TEMP_MAX', 'ADR_TEMP_MIN',
#        'HYS_PRECIP_ACC', 'HYS_PRECIP_INCR', 'HYS_SNOW_DEPTH',
#        'HYS_SNOW_WATER_CONTENT', 'HYS_TEMP_AVG', 'HYS_TEMP_MAX',
#        'HYS_TEMP_MIN', 'DUN_PRECIP_ACC', 'DUN_TEMP_AVG', 'DUN_TEMP_MAX',
#        'DUN_TEMP_MIN', 'SGP_PRECIP_ACC', 'SGP_PRECIP_INCR', 'SGP_TEMP_AVG',
#        'SGP_TEMP_MAX', 'SGP_TEMP_MIN', 'FRN_PRECIP_ACC', 'FRN_PRECIP_INCR',
#        'FRN_SNOW_DEPTH', 'FRN_SNOW_WATER_CONTENT', 'FRN_TEMP_AVG',
#        'FRN_TEMP_MAX', 'FRN_TEMP_MIN', 'PFH_PRECIP_ACC', 'PFH_PRECIP_INCR',
#        'PFH_TEMP_AVG', 'PFH_TEMP_MAX', 'PFH_TEMP_MIN'],
#       dtype='object')

# %% [markdown]
# #### Exponential moving average smoothing

# %%
"""
Exponential moving average smoothing

- Uses past 30 periods or days to inform prediction (give them more weight) in order to capture trends
- Span corresponds to what is commonly called an “N-day EW moving average”
"""

def smooth(df):
  for col in df.columns:
    df[col] = df[col].ewm(span=30.0, ignore_na=True).mean(engine='numba')
  
  return df

# %%
smoothed_basin_inflow = smooth(basin_inflow.copy())
smoothed_basin_inflow.head()
# Out:
#         INFLOW  NFD_MEAN_FLOW  OXB_RIVER_STAGE  OXB_RIVER_DISCHARGE  \
# 0   977.000000     152.000000         8.585417           169.666667
# 1  1020.400000     142.700000         8.535042           161.550694
# 2  1266.467234     136.758238         8.466833           151.303576
# 3  1389.227747     133.793951         8.863674           317.046944
# 4  2682.196020     132.020639         9.323006           455.882913
#
#    CBR_RIVER_STAGE  CBR_RIVER_DISCHARGE  ADR_PRECIP_ACC  ADR_PRECIP_INCR  \
# 0         4.445833           281.045455        9.520000         0.000000
# 1         3.336507           509.173359        9.520000         0.000000
# 2         3.214408           725.049078        9.605391         0.085391
# 3         3.058778           764.150249       10.066807         0.480678
# 4         3.143714           880.106011       10.497554         0.526028
#
#    ADR_TEMP_AVG  ADR_TEMP_MAX  ...  FRN_SNOW_DEPTH  FRN_SNOW_WATER_CONTENT  \
# 0     44.000000     58.000000  ...       30.000000                7.900000
# 1     45.550000     57.483333  ...       30.000000                7.889667
# 2     45.354313     54.820807  ...       30.000000                7.879111
# 3     45.532223     53.492499  ...       30.826609                7.986815
# 4     44.501033     51.787774  ...       31.321108                8.051247
#
#    FRN_TEMP_AVG  FRN_TEMP_MAX  FRN_TEMP_MIN  PFH_PRECIP_ACC  PFH_PRECIP_INCR  \
# 0     44.000000     55.000000     37.000000        7.720000         0.040000
# 1     40.900000     50.350000     34.416667        7.740667         0.040000
# 2     37.021844     44.888560     31.066272        7.747545         0.025768
# 3     35.362606     41.612828     30.221402        8.643715         0.911406
# 4     34.370008     39.653201     29.715979        9.416452         0.940664
#
#    PFH_TEMP_AVG  PFH_TEMP_MAX  PFH_TEMP_MIN
# 0     40.000000     61.000000     30.000000
# 1     39.483333     62.033333     29.483333
# 2     39.667160     58.819326     29.311366
# 3     39.483333     55.562671     30.052183
# 4     38.008218     51.566738     30.495358
#
# [5 rows x 39 columns]

# %% [markdown]
# #### Remove seasonality

# %%
"""
Make data stationary

Seasonal data is differenced by substracting an observation from the same time in the previous cycle.
"""

def difference(dataset, interval=1):
    cols = []
    for col in dataset.columns: 
        col_data = dataset[col]
        series = col_data.values
        diff = list()
        for i in range(interval, len(series)):
            value = series[i] - series[i - interval]
            diff.append(value)
        cols.append(pd.Series(diff))
    
    return pd.concat(cols, axis=1)

# %%
days = 365

stationary_basin_inflow = difference(smoothed_basin_inflow, days)
stationary_basin_inflow.index = smoothed_basin_inflow.index[days:]
stationary_basin_inflow.columns = smoothed_basin_inflow.columns
stationary_basin_inflow.reset_index(drop=True, inplace=True)
print("Null/NaN count: ", stationary_basin_inflow.isnull().sum().sum())
# Out:
# Null/NaN count:  0

# %%
stationary_basin_inflow.head()
# Out:
#         INFLOW  NFD_MEAN_FLOW  OXB_RIVER_STAGE  OXB_RIVER_DISCHARGE  \
# 0   313.381625     -29.948597         1.267748           328.122057
# 1   327.569908      11.928732         1.335177           339.472091
# 2   125.633647      35.636382         1.375764           338.836019
# 3     2.479529      43.220371         0.957115           164.341709
# 4 -1295.115020      45.831469         0.489749            22.281741
#
#    CBR_RIVER_STAGE  CBR_RIVER_DISCHARGE  ADR_PRECIP_ACC  ADR_PRECIP_INCR  \
# 0        -2.698053           161.105800       -4.372491         0.151906
# 1        -1.590250           -68.803367       -4.198782         0.178235
# 2        -1.489119          -294.267474       -4.121670         0.081345
# 3        -1.319207          -326.421759       -4.431068        -0.324699
# 4        -1.392986          -436.991724       -4.719605        -0.380113
#
#    ADR_TEMP_AVG  ADR_TEMP_MAX  ...  FRN_SNOW_DEPTH  FRN_SNOW_WATER_CONTENT  \
# 0      0.121939     -6.413691  ...      -17.288084               -1.700984
# 1     -1.693993     -6.386464  ...      -16.559821               -1.572523
# 2     -1.940629     -4.052768  ...      -15.878542               -1.451461
# 3     -2.338777     -2.903043  ...      -16.067826               -1.455787
# 4     -1.320067     -1.107315  ...      -14.417730               -1.423511
#
#    FRN_TEMP_AVG  FRN_TEMP_MAX  FRN_TEMP_MIN  PFH_PRECIP_ACC  PFH_PRECIP_INCR  \
# 0    -11.105608    -14.746997     -9.483165       -0.778717         0.202783
# 1     -8.127827    -10.629448     -6.804144       -0.470434         0.295506
# 2     -4.364004     -5.666108     -3.364234       -0.164425         0.293254
# 3     -2.811724     -2.856341     -2.435625       -0.765312        -0.610386
# 4     -1.661118     -0.622939     -1.787349       -1.259236        -0.656484
#
#    PFH_TEMP_AVG  PFH_TEMP_MAX  PFH_TEMP_MIN
# 0     -1.782846     -9.608046      0.235409
# 1     -1.667286    -11.569893      0.672372
# 2     -2.484406     -9.030946      0.189132
# 3     -2.634950     -6.018703     -0.842039
# 4     -1.150053     -1.864316     -1.169740
#
# [5 rows x 39 columns]

# %%
stationary_basin_inflow.to_excel(f'{DATA_PATH}/Custom/stationary_basin_inflow.xlsx')
